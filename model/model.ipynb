# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes.csv")

# %%
# Pregnancies: To express the Number of pregnancies

# Glucose: To express the Glucose level in blood

# BloodPressure: To express the Blood pressure measurement

# SkinThickness: To express the thickness of the skin

# Insulin: To express the Insulin level in blood

# BMI: To express the Body mass index

# DiabetesPedigreeFunction: To express the Diabetes percentage

# Age: To express the age

# Outcome: To express the final result 1 is Yes Diagnosis and 0 is No Diagnosis

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 1377            1      189             60             23      846  30.1
# 1378            1       84             64             23      115  36.9
# 1379            2       92             52              0        0  30.1
# 1380            0      125             96              0        0  22.5
# 1381            1      124             74             36        0  27.8
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# 4                        2.288   33        1
# ...                        ...  ...      ...
# 1377                     0.398   59        1
# 1378                     0.471   28        0
# 1379                     0.141   22        0
# 1380                     0.262   21        0
# 1381                     0.100   30        0
#
# [1382 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1382 non-null   int64
#  1   Glucose                   1382 non-null   int64
#  2   BloodPressure             1382 non-null   int64
#  3   SkinThickness             1382 non-null   int64
#  4   Insulin                   1382 non-null   int64
#  5   BMI                       1382 non-null   float64
#  6   DiabetesPedigreeFunction  1382 non-null   float64
#  7   Age                       1382 non-null   int64
#  8   Outcome                   1382 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 97.3 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Outcome'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Age'].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
df['DiabetesPedigreeFunction'].unique()
# Out:
# array([0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158,
#        0.232, 0.191, 0.537, 1.441, 0.398, 0.587, 0.484, 0.551, 0.254,
#        0.183, 0.529, 0.704, 0.388, 0.451, 0.263, 0.205, 0.257, 0.487,
#        0.245, 0.337, 0.546, 0.851, 0.267, 0.188, 0.512, 0.966, 0.42 ,
#        0.665, 0.503, 1.39 , 0.271, 0.696, 0.235, 0.721, 0.294, 1.893,
#        0.564, 0.586, 0.344, 0.305, 0.491, 0.526, 0.342, 0.467, 0.718,
#        0.962, 1.781, 0.173, 0.304, 0.27 , 0.699, 0.258, 0.203, 0.855,
#        0.845, 0.334, 0.189, 0.867, 0.411, 0.583, 0.231, 0.396, 0.14 ,
#        0.391, 0.37 , 0.307, 0.102, 0.767, 0.237, 0.227, 0.698, 0.178,
#        0.324, 0.153, 0.165, 0.443, 0.261, 0.277, 0.761, 0.255, 0.13 ,
#        0.323, 0.356, 0.325, 1.222, 0.179, 0.262, 0.283, 0.93 , 0.801,
#        0.207, 0.287, 0.336, 0.247, 0.199, 0.543, 0.192, 0.588, 0.539,
#        0.735, 0.804, 0.661, 0.549, 0.825, 0.423, 1.034, 0.16 , 0.341,
#        0.68 , 0.591, 0.3  , 0.121, 0.502, 0.401, 0.601, 0.748, 0.338,
#        0.43 , 0.892, 0.813, 0.693, 0.575, 0.371, 0.206, 0.417, 1.154,
#        0.925, 0.175, 1.699, 0.682, 0.194, 0.4  , 0.1  , 1.258, 0.482,
#        0.138, 0.593, 0.878, 0.157, 1.282, 0.141, 0.246, 1.698, 1.461,
#        0.347, 0.362, 0.393, 0.144, 0.732, 0.115, 0.465, 0.649, 0.871,
#        0.149, 0.695, 0.303, 0.61 , 0.73 , 0.447, 0.455, 0.133, 0.155,
#        1.162, 1.292, 0.182, 1.394, 0.217, 0.631, 0.88 , 0.614, 0.332,
#        0.366, 0.181, 0.828, 0.335, 0.856, 0.886, 0.439, 0.253, 0.598,
#        0.904, 0.483, 0.565, 0.118, 0.177, 0.176, 0.295, 0.441, 0.352,
#        0.826, 0.97 , 0.595, 0.317, 0.265, 0.646, 0.426, 0.56 , 0.515,
#        0.453, 0.785, 0.734, 1.174, 0.488, 0.358, 1.096, 0.408, 1.182,
#        0.222, 1.057, 0.766, 0.171])

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
df['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
df['SkinThickness'].unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
df['Insulin'].unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
#        183,  91,  46, 440, 159, 540, 200, 335, 387,  22, 291, 392, 178,
#        127, 510,  16, 112], dtype=int64)

# %%
df['BMI'].unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
#        41.8, 35.8, 37.8, 28.8, 23.6, 35.7, 36.7, 45.2, 44. , 46.2, 35. ,
#        43.6, 44.1, 18.4, 29.2, 25.9, 32.1, 36.3, 40. , 25.1, 27.5, 45.6,
#        27.8, 24.9, 25.3, 37.9, 27. , 26. , 38.7, 20.8, 36.1, 30.7, 32.3,
#        52.9, 21. , 39.7, 25.5, 26.2, 19.3, 38.1, 23.5, 45.5, 23.1, 39.9,
#        36.8, 21.8, 41. , 42.2, 34.4, 27.2, 36.5, 29.8, 39.2, 38.4, 36.2,
#        48.3, 20. , 22.3, 45.7, 23.7, 22.1, 42.1, 42.4, 18.2, 26.4, 45.3,
#        37. , 24.5, 32.2, 59.4, 21.2, 26.7, 30.2, 46.1, 41.3, 38.8, 35.2,
#        42.3, 40.7, 46.5, 33.5, 37.3, 30.3, 26.3, 21.7, 36.4, 28.5, 26.9,
#        38.6, 31.3, 19.5, 20.1, 40.8, 23.4, 28.3, 38.9, 57.3, 35.6, 49.6,
#        44.6, 24.1, 44.5, 41.2, 49.3, 46.3])

# %%
import seaborn as sns

# %%
sns.countplot(x='Outcome', data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1382 non-null   int64
#  1   Glucose                   1382 non-null   int64
#  2   BloodPressure             1382 non-null   int64
#  3   SkinThickness             1382 non-null   int64
#  4   Insulin                   1382 non-null   int64
#  5   BMI                       1382 non-null   float64
#  6   DiabetesPedigreeFunction  1382 non-null   float64
#  7   Age                       1382 non-null   int64
#  8   Outcome                   1382 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 97.3 KB

# %%
sns.distplot(df['Age'])
df['Age'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\525608211.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# 1.1350719136565706

# %%
sns.distplot(df['DiabetesPedigreeFunction'])
df['DiabetesPedigreeFunction'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\1644824479.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['DiabetesPedigreeFunction'])
# 1.943521169723091

# %%
sns.distplot(df['BMI'])
df['BMI'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\721139507.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'])
# -0.4789101690784244

# %%
sns.distplot(df['Insulin'])
df['Insulin'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\282091508.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Insulin'])
# 2.3262488449742373

# %%
sns.distplot(df['SkinThickness'])
df['SkinThickness'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\1107717168.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SkinThickness'])
# 0.06744122274991736

# %%
sns.distplot(df['BloodPressure'])
df['BloodPressure'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\341243809.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BloodPressure'])
# -1.8585823435472142

# %%
sns.distplot(df['Glucose'])
df['Glucose'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_18056\363115285.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Glucose'])
# 0.1511513267811641

# %%
sns.countplot(x='Pregnancies', data=df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
import plotly.express as px

# %%
sns.countplot(x='Pregnancies', hue= 'Outcome', data=df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
corr_matrix=df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix,annot=True,fmt='.2g',linewidths=4)
plt.title('Correlation Matrix',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.figure(figsize=(30,14))
preg_group=df.groupby('Pregnancies').agg({'Age':['min','max','mean']})
df_preg_group=pd.DataFrame(preg_group)
df_preg_group.plot.bar(width=0.4,color=['lightblue','lightpink','lightgreen'])
plt.show()

# %%
sns.pairplot(df[["Glucose", "BloodPressure", "BMI"]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots (figsize= (15, 10))
sns.boxplot (df,width= 0.5, ax=ax,fliersize=5)
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 1377            1      189             60             23      846  30.1
# 1378            1       84             64             23      115  36.9
# 1379            2       92             52              0        0  30.1
# 1380            0      125             96              0        0  22.5
# 1381            1      124             74             36        0  27.8
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# 4                        2.288   33        1
# ...                        ...  ...      ...
# 1377                     0.398   59        1
# 1378                     0.471   28        0
# 1379                     0.141   22        0
# 1380                     0.262   21        0
# 1381                     0.100   30        0
#
# [1382 rows x 9 columns]

# %%
X = df.drop(columns=['Outcome'])
y = df['Outcome']

# %%
X
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 1377            1      189             60             23      846  30.1
# 1378            1       84             64             23      115  36.9
# 1379            2       92             52              0        0  30.1
# 1380            0      125             96              0        0  22.5
# 1381            1      124             74             36        0  27.8
#
#       DiabetesPedigreeFunction  Age
# 0                        0.627   50
# 1                        0.351   31
# 2                        0.672   32
# 3                        0.167   21
# 4                        2.288   33
# ...                        ...  ...
# 1377                     0.398   59
# 1378                     0.471   28
# 1379                     0.141   22
# 1380                     0.262   21
# 1381                     0.100   30
#
# [1382 rows x 8 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1377    1
# 1378    0
# 1379    0
# 1380    0
# 1381    0
# Name: Outcome, Length: 1382, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
ro=RandomOverSampler()
x_data,y_data=ro.fit_resample(X,y)

# %%
from collections import Counter
print("Actual Data:",Counter(y))
# Out:
# Actual Data: Counter({0: 900, 1: 482})

# %%
print("Artificial Data:",Counter(y_data))
# Out:
# Artificial Data: Counter({1: 900, 0: 900})

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, cross_val_score

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Define the base models
level0 = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('svc', SVC(kernel='linear', probability=True, random_state=42)),
    ('xgb', xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)),
    ('knn', KNeighborsClassifier())
]

# Define the meta-model
level1 = DecisionTreeClassifier()

# Create the stacking ensemble
stacking_model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)

# %%
stacking_model.fit(X_train, y_train)
# Out:
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:47:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:52:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:52:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:52:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:52:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Promantus\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:52:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# StackingClassifier(cv=5,
#                    estimators=[('rf', RandomForestClassifier(random_state=42)),
#                                ('svc',
#                                 SVC(kernel='linear', probability=True,
#                                     random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metr...
#                                               learning_rate=None, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...)),
#                                ('knn', KNeighborsClassifier())],
#                    final_estimator=DecisionTreeClassifier())

# %%
y_train_pred = stacking_model.predict(X_train)

# Calculate training accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f'Training Accuracy: {train_accuracy:.4f}')
# Out:
# Training Accuracy: 0.9929

# %%
# Make predictions
y_pred = stacking_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9222

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       273
#            1       0.93      0.91      0.92       267
#
#     accuracy                           0.92       540
#    macro avg       0.92      0.92      0.92       540
# weighted avg       0.92      0.92      0.92       540

# %%
y_pred = stacking_model.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[255,  18],
#        [ 24, 243]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(stacking_model,open('stacking.pkl','wb'))
stacking = pickle.load(open('stacking.pkl','rb'))

# %%
# pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\promantus\appdata\local\programs\python\python312\lib\site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\promantus\appdata\local\programs\python\python312\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\promantus\appdata\local\programs\python\python312\lib\site-packages (from lightgbm) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 633, number of negative: 627
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 826
# [LightGBM] [Info] Number of data points in the train set: 1260, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502381 -> initscore=0.009524
# [LightGBM] [Info] Start training from score 0.009524
# LGBMClassifier()

# %%
clf.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 0.95

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       273
#            1       0.93      0.98      0.95       267
#
#     accuracy                           0.95       540
#    macro avg       0.95      0.95      0.95       540
# weighted avg       0.95      0.95      0.95       540

# %%
y_pred = clf.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[252,  21],
#        [  6, 261]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
pickle.dump(clf,open('lightgbm.pkl','wb'))
lightgbm = pickle.load(open('lightgbm.pkl','rb'))

# %%
# pip install catboost

# %%
from catboost import CatBoostClassifier

cat = CatBoostClassifier(
    iterations=500, 
    learning_rate=0.1, 
    #loss_function='CrossEntropy'
)

# %%
cat.fit(X,y)
# Out:
# 0:	learn: 0.6408820	total: 146ms	remaining: 1m 12s
# 1:	learn: 0.6045566	total: 156ms	remaining: 38.9s
# 2:	learn: 0.5714574	total: 168ms	remaining: 27.8s
# 3:	learn: 0.5425270	total: 179ms	remaining: 22.2s
# 4:	learn: 0.5220700	total: 190ms	remaining: 18.8s
# 5:	learn: 0.5037236	total: 200ms	remaining: 16.4s
# 6:	learn: 0.4848449	total: 212ms	remaining: 14.9s
# 7:	learn: 0.4708181	total: 223ms	remaining: 13.7s
# 8:	learn: 0.4538672	total: 233ms	remaining: 12.7s
# 9:	learn: 0.4442572	total: 245ms	remaining: 12s
# 10:	learn: 0.4338872	total: 253ms	remaining: 11.2s
# 11:	learn: 0.4278964	total: 259ms	remaining: 10.5s
# 12:	learn: 0.4195658	total: 264ms	remaining: 9.88s
# 13:	learn: 0.4126032	total: 269ms	remaining: 9.35s
# 14:	learn: 0.4035498	total: 274ms	remaining: 8.84s
# 15:	learn: 0.3944815	total: 278ms	remaining: 8.4s
# 16:	learn: 0.3887090	total: 284ms	remaining: 8.07s
# 17:	learn: 0.3837010	total: 288ms	remaining: 7.71s
# 18:	learn: 0.3798820	total: 292ms	remaining: 7.39s
# 19:	learn: 0.3779069	total: 296ms	remaining: 7.09s
# 20:	learn: 0.3722038	total: 300ms	remaining: 6.85s
# 21:	learn: 0.3660843	total: 304ms	remaining: 6.6s
# 22:	learn: 0.3628524	total: 308ms	remaining: 6.38s
# 23:	learn: 0.3594884	total: 312ms	remaining: 6.19s
# 24:	learn: 0.3547021	total: 316ms	remaining: 6.01s
# 25:	learn: 0.3519647	total: 320ms	remaining: 5.83s
# 26:	learn: 0.3485014	total: 324ms	remaining: 5.67s
# 27:	learn: 0.3415687	total: 328ms	remaining: 5.53s
# 28:	learn: 0.3374769	total: 332ms	remaining: 5.4s
# 29:	learn: 0.3322195	total: 338ms	remaining: 5.29s
# 30:	learn: 0.3295377	total: 342ms	remaining: 5.17s
# 31:	learn: 0.3250915	total: 346ms	remaining: 5.06s
# 32:	learn: 0.3222549	total: 351ms	remaining: 4.96s
# 33:	learn: 0.3177205	total: 355ms	remaining: 4.86s
# 182:	learn: 0.0891694	total: 1.07s	remaining: 1.86s
# 183:	learn: 0.0885756	total: 1.08s	remaining: 1.86s
# 184:	learn: 0.0880958	total: 1.08s	remaining: 1.85s
# 185:	learn: 0.0872316	total: 1.09s	remaining: 1.84s
# 186:	learn: 0.0862810	total: 1.1s	remaining: 1.83s
# 187:	learn: 0.0854238	total: 1.1s	remaining: 1.83s
# 188:	learn: 0.0848261	total: 1.1s	remaining: 1.82s
# 189:	learn: 0.0842689	total: 1.11s	remaining: 1.81s
# 190:	learn: 0.0834377	total: 1.12s	remaining: 1.8s
# 191:	learn: 0.0824976	total: 1.12s	remaining: 1.8s
# 192:	learn: 0.0820015	total: 1.13s	remaining: 1.79s
# 193:	learn: 0.0812038	total: 1.13s	remaining: 1.78s
# 194:	learn: 0.0803631	total: 1.14s	remaining: 1.78s
# 195:	learn: 0.0799650	total: 1.14s	remaining: 1.77s
# 196:	learn: 0.0797981	total: 1.15s	remaining: 1.77s
# 197:	learn: 0.0797266	total: 1.15s	remaining: 1.76s
# 198:	learn: 0.0789018	total: 1.16s	remaining: 1.75s
# 199:	learn: 0.0784226	total: 1.16s	remaining: 1.75s
# 200:	learn: 0.0779832	total: 1.17s	remaining: 1.74s
# 201:	learn: 0.0776590	total: 1.17s	remaining: 1.73s
# 202:	learn: 0.0770773	total: 1.18s	remaining: 1.73s
# 203:	learn: 0.0765138	total: 1.18s	remaining: 1.72s
# 204:	learn: 0.0760460	total: 1.19s	remaining: 1.71s
# 205:	learn: 0.0752142	total: 1.19s	remaining: 1.7s
# 206:	learn: 0.0747788	total: 1.2s	remaining: 1.7s
# 207:	learn: 0.0742696	total: 1.21s	remaining: 1.69s
# 208:	learn: 0.0732076	total: 1.21s	remaining: 1.68s
# 209:	learn: 0.0727640	total: 1.21s	remaining: 1.68s
# 210:	learn: 0.0725794	total: 1.22s	remaining: 1.67s
# 211:	learn: 0.0720603	total: 1.23s	remaining: 1.67s
# 212:	learn: 0.0716922	total: 1.23s	remaining: 1.66s
# 213:	learn: 0.0712333	total: 1.24s	remaining: 1.65s
# 214:	learn: 0.0707830	total: 1.24s	remaining: 1.65s
# 215:	learn: 0.0706659	total: 1.25s	remaining: 1.64s
# 216:	learn: 0.0702706	total: 1.25s	remaining: 1.63s
# 217:	learn: 0.0694810	total: 1.26s	remaining: 1.63s
# 218:	learn: 0.0687451	total: 1.26s	remaining: 1.62s
# 219:	learn: 0.0681027	total: 1.27s	remaining: 1.61s
# 220:	learn: 0.0678932	total: 1.27s	remaining: 1.6s
# 221:	learn: 0.0675347	total: 1.28s	remaining: 1.6s
# 222:	learn: 0.0672125	total: 1.28s	remaining: 1.59s
# 223:	learn: 0.0664843	total: 1.29s	remaining: 1.59s
# 224:	learn: 0.0663342	total: 1.29s	remaining: 1.58s
# 225:	learn: 0.0658675	total: 1.3s	remaining: 1.57s
# 226:	learn: 0.0656122	total: 1.3s	remaining: 1.57s
# 227:	learn: 0.0653023	total: 1.31s	remaining: 1.56s
# 228:	learn: 0.0649977	total: 1.31s	remaining: 1.55s
# 229:	learn: 0.0647139	total: 1.32s	remaining: 1.54s
# 230:	learn: 0.0642672	total: 1.32s	remaining: 1.54s
# 231:	learn: 0.0635776	total: 1.32s	remaining: 1.53s
# 232:	learn: 0.0631532	total: 1.33s	remaining: 1.52s
# 233:	learn: 0.0627397	total: 1.33s	remaining: 1.52s
# 234:	learn: 0.0622048	total: 1.34s	remaining: 1.51s
# 235:	learn: 0.0616724	total: 1.34s	remaining: 1.5s
# 236:	learn: 0.0612709	total: 1.35s	remaining: 1.5s
# 237:	learn: 0.0608102	total: 1.35s	remaining: 1.49s
# 238:	learn: 0.0602783	total: 1.36s	remaining: 1.48s
# 239:	learn: 0.0599742	total: 1.36s	remaining: 1.48s
# 240:	learn: 0.0593020	total: 1.37s	remaining: 1.47s
# 241:	learn: 0.0590251	total: 1.37s	remaining: 1.46s
# 242:	learn: 0.0587228	total: 1.38s	remaining: 1.46s
# 243:	learn: 0.0583155	total: 1.38s	remaining: 1.45s
# 244:	learn: 0.0579297	total: 1.39s	remaining: 1.45s
# 245:	learn: 0.0577565	total: 1.39s	remaining: 1.44s
# 246:	learn: 0.0573583	total: 1.4s	remaining: 1.43s
# 247:	learn: 0.0570101	total: 1.4s	remaining: 1.42s
# 248:	learn: 0.0564110	total: 1.41s	remaining: 1.42s
# 249:	learn: 0.0561025	total: 1.41s	remaining: 1.41s
# 250:	learn: 0.0557491	total: 1.42s	remaining: 1.4s
# 251:	learn: 0.0554612	total: 1.42s	remaining: 1.4s
# 252:	learn: 0.0549138	total: 1.43s	remaining: 1.39s
# 253:	learn: 0.0546130	total: 1.43s	remaining: 1.39s
# 254:	learn: 0.0542381	total: 1.44s	remaining: 1.38s
# 255:	learn: 0.0537856	total: 1.44s	remaining: 1.37s
# 256:	learn: 0.0534504	total: 1.44s	remaining: 1.36s
# 257:	learn: 0.0532072	total: 1.45s	remaining: 1.36s
# 258:	learn: 0.0528962	total: 1.45s	remaining: 1.35s
# 259:	learn: 0.0525144	total: 1.46s	remaining: 1.35s
# 260:	learn: 0.0520079	total: 1.46s	remaining: 1.34s
# 261:	learn: 0.0518459	total: 1.47s	remaining: 1.33s
# 262:	learn: 0.0514034	total: 1.47s	remaining: 1.33s
# 263:	learn: 0.0512116	total: 1.48s	remaining: 1.32s
# 264:	learn: 0.0508116	total: 1.48s	remaining: 1.31s
# 265:	learn: 0.0503444	total: 1.49s	remaining: 1.31s
# 266:	learn: 0.0500707	total: 1.49s	remaining: 1.3s
# 267:	learn: 0.0498119	total: 1.5s	remaining: 1.29s
# 268:	learn: 0.0495335	total: 1.5s	remaining: 1.29s
# 269:	learn: 0.0493378	total: 1.5s	remaining: 1.28s
# 270:	learn: 0.0489916	total: 1.51s	remaining: 1.27s
# 271:	learn: 0.0484667	total: 1.51s	remaining: 1.27s
# 272:	learn: 0.0481831	total: 1.52s	remaining: 1.26s
# 273:	learn: 0.0480172	total: 1.52s	remaining: 1.26s
# 274:	learn: 0.0479060	total: 1.53s	remaining: 1.25s
# 275:	learn: 0.0476100	total: 1.53s	remaining: 1.24s
# 276:	learn: 0.0475099	total: 1.54s	remaining: 1.24s
# 277:	learn: 0.0472909	total: 1.54s	remaining: 1.23s
# 278:	learn: 0.0471333	total: 1.55s	remaining: 1.23s
# 279:	learn: 0.0468540	total: 1.55s	remaining: 1.22s
# 280:	learn: 0.0465250	total: 1.56s	remaining: 1.21s
# 281:	learn: 0.0459821	total: 1.56s	remaining: 1.21s
# 282:	learn: 0.0457429	total: 1.57s	remaining: 1.2s
# 283:	learn: 0.0454594	total: 1.57s	remaining: 1.19s
# 284:	learn: 0.0451559	total: 1.57s	remaining: 1.19s
# 285:	learn: 0.0449600	total: 1.58s	remaining: 1.18s
# 286:	learn: 0.0447181	total: 1.58s	remaining: 1.18s
# 287:	learn: 0.0443654	total: 1.59s	remaining: 1.17s
# 288:	learn: 0.0441046	total: 1.59s	remaining: 1.16s
# 289:	learn: 0.0439377	total: 1.6s	remaining: 1.16s
# 290:	learn: 0.0437640	total: 1.6s	remaining: 1.15s
# 291:	learn: 0.0434331	total: 1.61s	remaining: 1.15s
# 292:	learn: 0.0431412	total: 1.61s	remaining: 1.14s
# 293:	learn: 0.0428370	total: 1.62s	remaining: 1.13s
# 294:	learn: 0.0426879	total: 1.62s	remaining: 1.13s
# 295:	learn: 0.0424122	total: 1.63s	remaining: 1.12s
# 296:	learn: 0.0418782	total: 1.63s	remaining: 1.11s
# 297:	learn: 0.0417469	total: 1.63s	remaining: 1.11s
# 298:	learn: 0.0415629	total: 1.64s	remaining: 1.1s
# 299:	learn: 0.0412994	total: 1.64s	remaining: 1.1s
# 300:	learn: 0.0410401	total: 1.65s	remaining: 1.09s
# 301:	learn: 0.0405688	total: 1.66s	remaining: 1.08s
# 302:	learn: 0.0402936	total: 1.66s	remaining: 1.08s
# 303:	learn: 0.0401846	total: 1.66s	remaining: 1.07s
# 304:	learn: 0.0398319	total: 1.67s	remaining: 1.07s
# 305:	learn: 0.0395705	total: 1.67s	remaining: 1.06s
# 306:	learn: 0.0393336	total: 1.68s	remaining: 1.05s
# 307:	learn: 0.0389969	total: 1.68s	remaining: 1.05s
# 308:	learn: 0.0386526	total: 1.69s	remaining: 1.04s
# 309:	learn: 0.0384803	total: 1.69s	remaining: 1.04s
# 310:	learn: 0.0384121	total: 1.7s	remaining: 1.03s
# 311:	learn: 0.0380579	total: 1.7s	remaining: 1.03s
# 312:	learn: 0.0377962	total: 1.71s	remaining: 1.02s
# 313:	learn: 0.0375295	total: 1.71s	remaining: 1.01s
# 314:	learn: 0.0374197	total: 1.72s	remaining: 1.01s
# 315:	learn: 0.0372476	total: 1.72s	remaining: 1s
# 316:	learn: 0.0371058	total: 1.73s	remaining: 997ms
# 317:	learn: 0.0369269	total: 1.73s	remaining: 991ms
# 318:	learn: 0.0367867	total: 1.74s	remaining: 985ms
# 319:	learn: 0.0364490	total: 1.74s	remaining: 980ms
# 320:	learn: 0.0363189	total: 1.75s	remaining: 974ms
# 321:	learn: 0.0361056	total: 1.75s	remaining: 969ms
# 322:	learn: 0.0358378	total: 1.76s	remaining: 963ms
# 323:	learn: 0.0355816	total: 1.76s	remaining: 957ms
# 324:	learn: 0.0355183	total: 1.77s	remaining: 951ms
# 325:	learn: 0.0354254	total: 1.77s	remaining: 945ms
# 474:	learn: 0.0175468	total: 2.47s	remaining: 130ms
# 475:	learn: 0.0174656	total: 2.48s	remaining: 125ms
# 476:	learn: 0.0172870	total: 2.48s	remaining: 120ms
# 477:	learn: 0.0172542	total: 2.49s	remaining: 114ms
# 478:	learn: 0.0172044	total: 2.49s	remaining: 109ms
# 479:	learn: 0.0171332	total: 2.49s	remaining: 104ms
# 480:	learn: 0.0170794	total: 2.5s	remaining: 98.7ms
# 481:	learn: 0.0170743	total: 2.5s	remaining: 93.5ms
# 482:	learn: 0.0170256	total: 2.51s	remaining: 88.3ms
# 483:	learn: 0.0169671	total: 2.51s	remaining: 83ms
# 484:	learn: 0.0169064	total: 2.52s	remaining: 77.8ms
# 485:	learn: 0.0168272	total: 2.52s	remaining: 72.7ms
# 486:	learn: 0.0167358	total: 2.53s	remaining: 67.4ms
# 487:	learn: 0.0166941	total: 2.53s	remaining: 62.2ms
# 488:	learn: 0.0166393	total: 2.54s	remaining: 57.1ms
# 489:	learn: 0.0166059	total: 2.54s	remaining: 51.8ms
# 490:	learn: 0.0165508	total: 2.54s	remaining: 46.6ms
# 491:	learn: 0.0164723	total: 2.55s	remaining: 41.5ms
# 492:	learn: 0.0164254	total: 2.55s	remaining: 36.3ms
# 493:	learn: 0.0163828	total: 2.56s	remaining: 31.1ms
# 494:	learn: 0.0163539	total: 2.56s	remaining: 25.9ms
# 495:	learn: 0.0162812	total: 2.57s	remaining: 20.7ms
# 496:	learn: 0.0161717	total: 2.57s	remaining: 15.5ms
# 497:	learn: 0.0160539	total: 2.58s	remaining: 10.3ms
# 498:	learn: 0.0159935	total: 2.58s	remaining: 5.17ms
# 499:	learn: 0.0159328	total: 2.58s	remaining: 0us

# %%
cat.score(X,y)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = cat.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       273
#            1       1.00      1.00      1.00       267
#
#     accuracy                           1.00       540
#    macro avg       1.00      1.00      1.00       540
# weighted avg       1.00      1.00      1.00       540

# %%
y_pred = cat.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[273,   0],
#        [  0, 267]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(cat,open('catboost.pkl','wb'))
catboost = pickle.load(open('catboost.pkl','rb'))

# %%
from sklearn.tree import ExtraTreeClassifier

Models = ExtraTreeClassifier()

# %%
Models.fit(X_train,y_train)
# Out:
# ExtraTreeClassifier()

# %%
Models.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = Models.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 0.9333333333333333

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       273
#            1       0.89      0.99      0.94       267
#
#     accuracy                           0.93       540
#    macro avg       0.94      0.93      0.93       540
# weighted avg       0.94      0.93      0.93       540

# %%
y_pred = Models.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[241,  32],
#        [  4, 263]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
pickle.dump(Models,open('ExtraTreeClassifier.pkl','wb'))
ExtraTreeClassifier = pickle.load(open('ExtraTreeClassifier.pkl','rb'))
